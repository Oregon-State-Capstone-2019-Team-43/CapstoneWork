# %%
import librosa
import librosa.display
import os



path=r'..\V6_robot_recordings\2019-04-13 Cienna Nerdy Show at The Drake\jokes_and_pauses\joke_1.mp3'

if os.path.isfile(path):
    print ("File exist")
else:
    print ("File not exist")


y, sr = librosa.load(path,sr=None)
mfccs = librosa.feature.mfcc(y=y, sr=sr,n_mfcc=24)
# Out:
# File exist
# C:\ProgramData\Anaconda3\lib\site-packages\librosa\core\audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
print(mfccs)
# Out:
# [[-170.93704    -172.586      -172.15971    ... -205.36758
#   -224.92848    -275.69006   ]
#  [  94.08166      97.9572      101.426285   ...   91.97102
#     96.27988      94.93057   ]
#  [ -54.451004    -52.600994    -56.69017    ...  -34.487907
#    -30.605427    -18.447304  ]
#  ...
#  [  16.912426     11.233833      3.068618   ...   -5.131459
#     -8.7769      -13.888909  ]
#  [  -3.873805     -6.5613728    -9.040137   ...   -6.961501
#     -6.774417     -1.0822929 ]
#  [  -4.1422253    -1.7991168     3.3220487  ...   -2.3905904
#     -2.3331568     0.56838864]]
